# %% [raw]
# import pandas as pd

# %%
import csv

# %%
df=pd.read_csv(r"C:\Users\ghpu\JupyterNotebook\datasets\healthcare\healthcare.csv")

# %%
df.head(10)
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0   318439             21                  c                   3
# 1   318440             29                  a                   4
# 2   318441             26                  b                   2
# 3   318442              6                  a                   6
# 4   318443             28                  b                  11
# 5   318444             23                  a                   6
# 6   318445             26                  b                   2
# 7   318446             25                  e                   1
# 8   318447             23                  a                   6
# 9   318448             23                  a                   6
#
#   Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                    Z                                  3  gynecology
# 1                    X                                  2  gynecology
# ...

# %%
df.tail(10)
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 137047   455486              9                  d                   5
# 137048   455487             13                  a                   5
# 137049   455488             12                  a                   9
# 137050   455489             13                  a                   5
# 137051   455490             15                  c                   5
# 137052   455491             11                  b                   2
# 137053   455492             25                  e                   1
# 137054   455493             30                  c                   3
# 137055   455494              5                  a                   1
# 137056   455495              6                  a                   6
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 137047                    Z                                  2    gynecology
# ...

# %%
#137057 Total rows and 17 Total coloumns

# %%
a=(df[['case_id','patientid', 'Department', 'Type of Admission', 'Severity of Illness', 'Visitors with Patient', 'Age', 'Admission_Deposit']])

# %%
a
# Out:
#         case_id  patientid    Department Type of Admission  \
# 0        318439      17006    gynecology         Emergency
# 1        318440      17006    gynecology            Trauma
# 2        318441      17006    gynecology         Emergency
# 3        318442      17006    gynecology            Trauma
# 4        318443      17006    gynecology            Trauma
# ...         ...        ...           ...               ...
# 137052   455491      41160    anesthesia         Emergency
# 137053   455492      30985  radiotherapy         Emergency
# 137054   455493      81811    anesthesia            Urgent
# 137055   455494      57021    anesthesia            Trauma
# 137056   455495     126729    gynecology            Trauma
#
#        Severity of Illness  Visitors with Patient    Age  Admission_Deposit
# 0                 Moderate                      2  71-80             3095.0
# 1                 Moderate                      4  71-80             4018.0
# ...

# %%
a.to_csv(r'C:\Users\ghpu\JupyterNotebook\datasets\healthcare\important.csv',index=False)

# %%
df1=pd.read_csv(r'C:\Users\ghpu\JupyterNotebook\datasets\healthcare\important.csv')

# %%
df1
# Out:
#         case_id  patientid    Department Type of Admission  \
# 0        318439      17006    gynecology         Emergency
# 1        318440      17006    gynecology            Trauma
# 2        318441      17006    gynecology         Emergency
# 3        318442      17006    gynecology            Trauma
# 4        318443      17006    gynecology            Trauma
# ...         ...        ...           ...               ...
# 137052   455491      41160    anesthesia         Emergency
# 137053   455492      30985  radiotherapy         Emergency
# 137054   455493      81811    anesthesia            Urgent
# 137055   455494      57021    anesthesia            Trauma
# 137056   455495     126729    gynecology            Trauma
#
#        Severity of Illness  Visitors with Patient    Age  Admission_Deposit
# 0                 Moderate                      2  71-80             3095.0
# 1                 Moderate                      4  71-80             4018.0
# ...

# %%
df1.shape
# Out:
# (137057, 8)

# %%
df1.describe()
# Out:
#              case_id      patientid  Visitors with Patient  Admission_Deposit
# count  137057.000000  137057.000000          137057.000000      137057.000000
# mean   386967.000000   65877.903515               3.284531        4869.731097
# std     39565.092259   37942.997623               1.777270        1080.766723
# min    318439.000000       3.000000               0.000000        1800.000000
# 25%    352703.000000   32945.000000               2.000000        4178.000000
# 50%    386967.000000   65786.000000               3.000000        4731.000000
# 75%    421231.000000   98851.000000               4.000000        5398.000000
# max    455495.000000  131618.000000              32.000000       11920.000000

# %%
df1
# Out:
#         case_id  patientid    Department Type of Admission  \
# 0        318439      17006    gynecology         Emergency
# 1        318440      17006    gynecology            Trauma
# 2        318441      17006    gynecology         Emergency
# 3        318442      17006    gynecology            Trauma
# 4        318443      17006    gynecology            Trauma
# ...         ...        ...           ...               ...
# 137052   455491      41160    anesthesia         Emergency
# 137053   455492      30985  radiotherapy         Emergency
# 137054   455493      81811    anesthesia            Urgent
# 137055   455494      57021    anesthesia            Trauma
# 137056   455495     126729    gynecology            Trauma
#
#        Severity of Illness  Visitors with Patient    Age  Admission_Deposit
# 0                 Moderate                      2  71-80             3095.0
# 1                 Moderate                      4  71-80             4018.0
# ...

# %%
df1.sort_values(['Age'], ascending=True)
# Out:
#         case_id  patientid    Department Type of Admission  \
# 74582    393021      41723    gynecology            Urgent
# 122405   440844      37380    gynecology            Trauma
# 134804   453243     117968    gynecology         Emergency
# 134803   453242     117968    gynecology         Emergency
# 134796   453235      83139    gynecology         Emergency
# ...         ...        ...           ...               ...
# 32785    351224     121035  radiotherapy         Emergency
# 32786    351225     121035  radiotherapy            Trauma
# 100098   418537     116732    gynecology            Trauma
# 111827   430266      29818    gynecology         Emergency
# 45438    363877      33175    gynecology         Emergency
#
#        Severity of Illness  Visitors with Patient     Age  Admission_Deposit
# 74582             Moderate                      2    0-10             5375.0
# 122405            Moderate                      3    0-10             5619.0
# ...

# %%
df1.sort_values(['Admission_Deposit'], ascending=False)
# Out:
#         case_id  patientid    Department Type of Admission  \
# 33736    352175     117859  radiotherapy         Emergency
# 58137    376576      77032    gynecology         Emergency
# 101606   420045      15109    gynecology            Trauma
# 4104     322543     122930    gynecology         Emergency
# 12632    331071     130818    gynecology            Trauma
# ...         ...        ...           ...               ...
# 54012    372451      25721    gynecology            Trauma
# 41801    360240      97483    gynecology         Emergency
# 90411    408850      31262  radiotherapy         Emergency
# 89723    408162     114523    gynecology         Emergency
# 100446   418885      23216    gynecology         Emergency
#
#        Severity of Illness  Visitors with Patient    Age  Admission_Deposit
# 33736             Moderate                      4  71-80            11920.0
# 58137                Minor                      6  31-40            11293.0
# ...

# %%
   df1.loc[df1['Admission_Deposit']>5000.0]
# Out:
#         case_id  patientid  Department Type of Admission Severity of Illness  \
# 15       318454      40728  gynecology         Emergency            Moderate
# 18       318457      40728  anesthesia         Emergency            Moderate
# 19       318458      40728  anesthesia            Trauma            Moderate
# 20       318459      40728  gynecology            Urgent            Moderate
# 22       318461      40728  gynecology            Urgent            Moderate
# ...         ...        ...         ...               ...                 ...
# 137044   455483      14503  gynecology            Trauma            Moderate
# 137051   455490     118215  gynecology            Urgent               Minor
# 137052   455491      41160  anesthesia         Emergency               Minor
# 137054   455493      81811  anesthesia            Urgent               Minor
# 137055   455494      57021  anesthesia            Trauma               Minor
#
# ...

# %%
   df1.loc[df1['Age']=='21-30']
# Out:
#         case_id  patientid          Department Type of Admission  \
# 211      318650     101291          gynecology         Emergency
# 212      318651     101291          gynecology         Emergency
# 213      318652     101291          gynecology         Emergency
# 214      318653     101291          gynecology         Emergency
# 215      318654     101291          gynecology         Emergency
# ...         ...        ...                 ...               ...
# 136990   455429      45017          gynecology         Emergency
# 136998   455437      41026  TB & Chest disease            Urgent
# 137032   455471      40918          gynecology            Trauma
# 137050   455489      22878          gynecology         Emergency
# 137051   455490     118215          gynecology            Urgent
#
#        Severity of Illness  Visitors with Patient    Age  Admission_Deposit
# 211                  Minor                      2  21-30             4836.0
# ...

# %%
   df1.loc[df1['Type of Admission'] == 'Emergency']
# Out:
#         case_id  patientid    Department Type of Admission  \
# 0        318439      17006    gynecology         Emergency
# 2        318441      17006    gynecology         Emergency
# 7        318446      95946    gynecology         Emergency
# 11       318450      95946    gynecology         Emergency
# 14       318453      40728    gynecology         Emergency
# ...         ...        ...           ...               ...
# 137048   455487      55235    gynecology         Emergency
# 137049   455488      99515    gynecology         Emergency
# 137050   455489      22878    gynecology         Emergency
# 137052   455491      41160    anesthesia         Emergency
# 137053   455492      30985  radiotherapy         Emergency
#
#        Severity of Illness  Visitors with Patient    Age  Admission_Deposit
# 0                 Moderate                      2  71-80             3095.0
# 2                 Moderate                      3  71-80             4492.0
# ...

# %%
   df1.loc[(df1['Type of Admission'] == 'Emergency') & (df1['Severity of Illness'] == 'Minor')]
# Out:
#         case_id  patientid  Department Type of Admission Severity of Illness  \
# 36       318475      71555  gynecology         Emergency               Minor
# 37       318476      71555  gynecology         Emergency               Minor
# 38       318477      71555  gynecology         Emergency               Minor
# 39       318478       3199  gynecology         Emergency               Minor
# 78       318517      85286  gynecology         Emergency               Minor
# ...         ...        ...         ...               ...                 ...
# 137037   455476     101360  gynecology         Emergency               Minor
# 137038   455477     101360  gynecology         Emergency               Minor
# 137041   455480     124764  gynecology         Emergency               Minor
# 137045   455484      15705  gynecology         Emergency               Minor
# 137052   455491      41160  anesthesia         Emergency               Minor
#
# ...

# %%
df1.groupby(['Department']).mean()
# Out:
#                           case_id     patientid  Visitors with Patient  \
# Department
# TB & Chest disease  388645.320768  67552.716447               3.367827
# anesthesia          384714.503187  65732.036667               3.090251
# gynecology          387456.120931  65861.413537               3.290032
# radiotherapy        384649.949269  65694.318926               3.386594
# surgery             383097.512931  63601.853448               3.834052
#
#                     Admission_Deposit
# Department
# TB & Chest disease        5116.748860
# anesthesia                5300.521205
# gynecology                4799.752290
# radiotherapy              4947.810258
# surgery                   4914.581897

# %%
df1.groupby(['Type of Admission']).mean()
# Out:
#                          case_id     patientid  Visitors with Patient  \
# Type of Admission
# Emergency          386522.619015  65813.206700               3.469785
# Trauma             383198.900277  65874.761936               3.246228
# Urgent             399801.558424  66044.170094               2.956057
#
#                    Admission_Deposit
# Type of Admission
# Emergency                4763.401819
# Trauma                   4970.263885
# Urgent                   4813.123527

# %%
df1.groupby(['Severity of Illness']).mean()
# Out:
#                            case_id     patientid  Visitors with Patient  \
# Severity of Illness
# Extreme              378550.929593  65845.705786               3.428898
# Minor                396396.820470  66514.732794               3.197081
# Moderate             385096.296677  65578.287882               3.280447
#
#                      Admission_Deposit
# Severity of Illness
# Extreme                    4741.815258
# Minor                      4970.483737
# Moderate                   4862.022794

# %%
df1.groupby(['Visitors with Patient']).mean()
# Out:
#                              case_id      patientid  Admission_Deposit
# Visitors with Patient
# 0                      416601.416667   56955.583333        4900.500000
# 1                      388773.093146   67686.492091        5290.806678
# 2                      386623.221302   65867.481144        5040.031306
# 3                      387586.826493   66102.845192        4879.692109
# 4                      387618.219042   65736.312763        4739.890523
# 5                      385651.248352   66956.229304        4578.353114
# 6                      384995.854496   66144.114710        4560.137284
# 7                      387199.697719   64782.225285        4411.651141
# 8                      387280.787598   65563.847168        4413.538574
# 9                      388087.858929   63372.587500        4321.914286
# 10                     383558.824053   67181.534521        4330.084633
# 11                     381503.068966   54288.715517        4106.250000
# ...

# %%
df1.groupby(['Age']).mean()
# Out:
#               case_id     patientid  Visitors with Patient  Admission_Deposit
# Age
# 0-10    411239.123008  64115.906098               3.505544        5015.842689
# 11-20   398463.835140  64847.804449               3.067859        4936.306631
# 21-30   390953.425524  65920.652650               3.014449        4871.334763
# 31-40   386620.093686  66135.978642               3.079758        4795.864718
# 41-50   386368.267678  65873.903301               3.321019        4813.155770
# 51-60   385789.606421  66430.835556               3.537538        4883.256955
# 61-70   382639.562952  66472.282481               3.458478        4942.223815
# 71-80   381593.170224  64874.721311               3.386082        4940.216929
# 81-90   379282.369851  65194.969851               3.414925        4902.491940
# 91-100  385235.743802  68591.922314               3.771901        5027.454545

# %%
df1.groupby(['Admission_Deposit']).mean()
# Out:
#                     case_id  patientid  Visitors with Patient
# Admission_Deposit
# 1800.0             418885.0    23216.0                    2.0
# 1801.0             408162.0   114523.0                    3.0
# 1805.0             408850.0    31262.0                   20.0
# 1806.0             360240.0    97483.0                    3.0
# 1822.0             372451.0    25721.0                   12.0
# ...                     ...        ...                    ...
# 10538.0            378523.0    51203.0                    4.0
# 10549.0            346855.6    71470.6                    4.6
# 10560.0            420045.0    15109.0                    4.0
# 11293.0            376576.0    77032.0                    6.0
# 11920.0            352175.0   117859.0                    4.0
#
# [6609 rows x 3 columns]

# %%
import pandas as pd
df1['Severity of Illness']=pd.Categorical(df1['Severity of Illness'], ['Minor','Moderate','Extreme'], ordered=True)
df1['Severity of Illness']=df1['Severity of Illness'].cat.codes

# %%
df1
# Out:
#         case_id  patientid    Department Type of Admission  \
# 0        318439      17006    gynecology         Emergency
# 1        318440      17006    gynecology            Trauma
# 2        318441      17006    gynecology         Emergency
# 3        318442      17006    gynecology            Trauma
# 4        318443      17006    gynecology            Trauma
# ...         ...        ...           ...               ...
# 137052   455491      41160    anesthesia         Emergency
# 137053   455492      30985  radiotherapy         Emergency
# 137054   455493      81811    anesthesia            Urgent
# 137055   455494      57021    anesthesia            Trauma
# 137056   455495     126729    gynecology            Trauma
#
#         Severity of Illness  Visitors with Patient    Age  Admission_Deposit
# 0                         1                      2  71-80             3095.0
# 1                         1                      4  71-80             4018.0
# ...

# %%
df1['Department']=pd.Categorical(df1['Department'], ['anesthesia','gynecology','radiotherapy', 'surgery', 'TB & Chest disease'], ordered=False)
df1['Department']=df1['Department'].cat.codes

# %%
df1['Type of Admission']=pd.Categorical(df1['Type of Admission'], ['Trauma','Urgent','Emergency'], ordered=True)
df1['Type of Admission']=df1['Type of Admission'].cat.codes

# %%
import seaborn as sns

# %%
df2=df1.iloc[0:999, 0:8]

# %%
df2
# Out:
#      case_id  patientid  Department  Type of Admission  Severity of Illness  \
# 0     318439      17006           1                  2                    1
# 1     318440      17006           1                  0                    1
# 2     318441      17006           1                  2                    1
# 3     318442      17006           1                  0                    1
# 4     318443      17006           1                  0                    1
# ..       ...        ...         ...                ...                  ...
# 994   319433      84436           1                  0                    1
# 995   319434      84436           1                  0                    1
# 996   319435      84436           1                  0                    1
# 997   319436      84436           1                  1                    1
# 998   319437     107436           1                  0                    1
#
#      Visitors with Patient    Age  Admission_Deposit
# ...

# %%
sns.scatterplot(x="patientid",y="Admission_Deposit", data=df2)

# %%
sns.boxplot(x="patientid",y="Age", data=df2)

# %%
sns.scatterplot(x="patientid",y="Department", data=df2)

# %%
sns.boxplot(x="patientid",y="Severity of Illness", data=df2)

# %%
sns.scatterplot(x="patientid",y="Visitors with Patient", data=df2)

# %%
df2
# Out:
#      case_id  patientid  Department  Type of Admission  Severity of Illness  \
# 0     318439      17006           1                  2                    1
# 1     318440      17006           1                  0                    1
# 2     318441      17006           1                  2                    1
# 3     318442      17006           1                  0                    1
# 4     318443      17006           1                  0                    1
# ..       ...        ...         ...                ...                  ...
# 994   319433      84436           1                  0                    1
# 995   319434      84436           1                  0                    1
# 996   319435      84436           1                  0                    1
# 997   319436      84436           1                  1                    1
# 998   319437     107436           1                  0                    1
#
#      Visitors with Patient    Age  Admission_Deposit
# ...

# %%
df2.dtypes
# Out:
# case_id                    int64
# patientid                  int64
# Department                  int8
# Type of Admission           int8
# Severity of Illness         int8
# Visitors with Patient      int64
# Age                       object
# Admission_Deposit        float64
# dtype: object
