# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r'healthdata.csv')

# %%
df
# Out:
#      case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0          1              8                  c                   3
# 1          2              2                  c                   5
# 2          3             10                  e                   1
# 3          4             26                  b                   2
# 4          5             26                  b                   2
# ..       ...            ...                ...                 ...
# 995      996              4                  a                   4
# 996      997             23                  a                   6
# 997      998             14                  a                   1
# 998      999             13                  a                   5
# 999     1000              8                  c                   3
#
#     Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                      Z                                  3  radiotherapy
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   case_id                            1000 non-null   int64
#  1   Hospital_code                      1000 non-null   int64
#  2   Hospital_type_code                 1000 non-null   object
#  3   City_Code_Hospital                 1000 non-null   int64
#  4   Hospital_region_code               1000 non-null   object
#  5   Available Extra Rooms in Hospital  1000 non-null   int64
#  6   Department                         1000 non-null   object
#  7   Ward_Type                          1000 non-null   object
#  8   Ward_Facility_Code                 1000 non-null   object
#  9   Bed Grade                          999 non-null    float64
#  10  patientid                          1000 non-null   int64
# ...

# %%
# It has total of 18 columns : 2 float, 7 int, 9 object.

# %%
# 2 Float: 
# Bed Grade                          - Quantitative, 
# City_Code_Patient                  - Non-Quantitative.

# %%
# 7 Int: 
# case_id                            - Non-Quantitative, 
# Hospital_code                      - Non-Quantitative, 
# City_Code_Hospital                 - Non-Quantitative, 
# Available Extra Rooms in Hospital  - Quantitative,
# patientid                          - Non-Quantitative,
# Visitors with Patient              - Quantitative,
# Admission_Deposit                  - Quantitative

# %%
# 9 object:
# Hospital_type_code                 - Nominal    
# Hospital_region_code               - Nominal
# Department                         - Nominal
# Ward_Type                          - Nominal
# Ward_Facility_Code                 - Nominal
# Type of Admission                  - Ordinal
# Severity of Illness                - Ordinal
# Age                                - Ordinal
# Stay                               - Ordinal

# %%
# The objective of this data analysis is to predict the length of the stay of the patient. 
# So 'Stay' is the dependent variable.

# %%
# I dont want mean, median, mode and order for 
# case_id, patient_id, City_Code_Patient, Hospital_code, City_Code_Hospital,
# Hospital_type_code, Hospital_region_code, Ward_Type, Ward_Facility_Code.

# %%
# So i calculate the mean, median, mode and order for remaining 9 columns as order below,
# Bed Grade
# Available Extra Rooms in Hospital
# Visitors with Patient
# Admission_Deposit
# Department
# Type of Admission
# Severity of Illness
# Age
# Stay

# %%
import statistics

# %%
mean = df['Bed Grade'].mean()
mode = df['Bed Grade'].mode()
median = df['Bed Grade'].median()
print('Mean: ', mean)
print('Median: ', median)
print('Mode: ', mode)
# Out:
# Mean:  2.4734734734734736
# Median:  2.0
# Mode:  0    2.0
# dtype: float64

# %%
mean = df['Available Extra Rooms in Hospital'].mean()
mode = df['Available Extra Rooms in Hospital'].mode()
median = df['Available Extra Rooms in Hospital'].median()
print('Mean: ', mean)
print('Median: ', median)
print('Mode: ', mode)
# Out:
# Mean:  3.228
# Median:  3.0
# Mode:  0    2
# dtype: int64

# %%
mean = df['Visitors with Patient'].mean()
mode = df['Visitors with Patient'].mode()
median = df['Visitors with Patient'].median()
print('Mean: ', mean)
print('Median: ', median)
print('Mode: ', mode)
# Out:
# Mean:  3.21
# Median:  3.0
# Mode:  0    2
# dtype: int64

# %%
mean = df['Admission_Deposit'].mean()
mode = df['Admission_Deposit'].mode()
median = df['Admission_Deposit'].median()
print('Mean: ', mean)
print('Median: ', median)
print('Mode:\n',mode)
# Out:
# Mean:  4800.338
# Median:  4710.0
# Mode:
#  0    4628
# 1    4834
# 2    5040
# 3    5150
# 4    5180
# dtype: int64

# %%
df['Department'].value_counts()
# Out:
# gynecology            769
# radiotherapy          111
# anesthesia             92
# TB & Chest disease     28
# Name: Department, dtype: int64

# %%
mode = df['Department'].mode()
print('Mode:\n',mode)
# I dont use mean and median for categorical datatypes.
# Department group of gynecology is more in this dataset.
# Out:
# Mode:
#  0    gynecology
# dtype: object

# %%
df['Type of Admission'].value_counts()
# Out:
# Trauma       484
# Emergency    390
# Urgent       126
# Name: Type of Admission, dtype: int64

# %%
mode = df['Type of Admission'].mode()
print('Mode:\n',mode)
# I dont use mean and median for categorical datatypes.
# Type of Admission group of trauma is more in this dataset.
# Out:
# Mode:
#  0    Trauma
# dtype: object

# %%
df['Severity of Illness'].value_counts()
# Out:
# Moderate    578
# Extreme     326
# Minor        96
# Name: Severity of Illness, dtype: int64

# %%
mode = df['Severity of Illness'].mode()
print('Mode:\n',mode)
# I dont use mean and median for categorical datatypes.
# Severity of Illness group of moderate is more in this dataset.
# Out:
# Mode:
#  0    Moderate
# dtype: object

# %%
df['Age'].value_counts()
# Out:
# 31-40     220
# 41-50     214
# 51-60     162
# 61-70     133
# 71-80     124
# 21-30      63
# 81-90      51
# 20-Nov     27
# 0-10        6
# Name: Age, dtype: int64

# %%
mode = df['Age'].mode()
print('Mode:\n',mode)
# I dont use mean and median for categorical datatypes.
# Age group of 31-40 is more in this dataset
# Out:
# Mode:
#  0    31-40
# dtype: object

# %%
df['Stay'].value_counts()
# Out:
# 21-30                 298
# 20-Nov                182
# 31-40                 182
# 51-60                 124
# 0-10                   65
# 41-50                  46
# 71-80                  40
# 81-90                  25
# More than 100 Days     22
# 91-100                  8
# 61-70                   8
# Name: Stay, dtype: int64

# %%
mode = df['Stay'].mode()
print('Mode:\n',mode)
# I dont use mean and median for categorical datatypes.
# Stay group of 21-30 is more in this dataset
# Out:
# Mode:
#  0    21-30
# dtype: object

# %%
# Print standard deviation of 9 taken columns.

# %%
# So i calculate the standard deviation, variance for 9 columns as order below,
# Bed Grade
# Available Extra Rooms in Hospital
# Visitors with Patient
# Admission_Deposit
# Department
# Type of Admission
# Severity of Illness
# Age
# Stay

# %%
print('Bed Grade Std: ',df['Bed Grade'].std())
print('Bed Grade Var: ',df['Bed Grade'].var())
print('Available Extra Rooms in Hospital Std: ',df['Available Extra Rooms in Hospital'].std())
print('Available Extra Rooms in Hospital Var: ',df['Available Extra Rooms in Hospital'].var())
print('Visitors with Patient: ',df['Visitors with Patient'].std())
print('Visitors with Patient: ',df['Visitors with Patient'].var())
print('Admission_Deposit Std: ',df['Admission_Deposit'].std())
print('Admission_Deposit Var: ',df['Admission_Deposit'].var())
# Categorical data no need std and var.
# Out:
# Bed Grade Std:  0.842892628401196
# Bed Grade Var:  0.7104679830130768
# Available Extra Rooms in Hospital Std:  1.2072586605502054
# Available Extra Rooms in Hospital Var:  1.4574734734734758
# Visitors with Patient:  1.5186198359715297
# Visitors with Patient:  2.3062062062061957
# Admission_Deposit Std:  1050.736485003217
# Admission_Deposit Var:  1104047.1609169156

# %%
# Understanding what plot to use at what situation?
# Generally data are classified as numeric, ordinal, nominal
# Depends on data types, we can use different plots.

# %%
# Box plot
sns.set(style="whitegrid")
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Admission_Deposit', data=df, orient="v")

# %%
# BoxPlot Interpetation:
# Here, I understood, it has max~10,000, min~2000, median~4700, q1~4050, q2~5400

# %%
# Histogram
# It displays the frequency of data in dataset.
plt.figure(figsize=(14,8))
sns.distplot(df['Visitors with Patient'], kde=False)

# %%
# In histogram, we can see no. of visitors of 2 is highest and they visit nearly 500 out of 1000 patients.

# %%
# Exploring Categorical data

# %%
type_counts = df['Severity of Illness'].value_counts()
df2 = pd.DataFrame({'Severity of Illness': type_counts}, 
                     index = ['Minor', 'Moderate', 'Extreme']
                   )
df2.plot.pie(y='Severity of Illness', figsize=(7,7), autopct='%1.1f%%')

# %%
type_counts = df['Department'].value_counts()
df2 = pd.DataFrame({'Department': type_counts}, 
                     index = ['gynecology', 'radiotherapy', 'TB & Chest disease', 'anesthesia']
                   )
df2.plot.pie(y='Department', figsize=(7,7), autopct='%1.1f%%')

# %%
type_counts = df['Type of Admission'].value_counts()
df2 = pd.DataFrame({'Type of Admission': type_counts}, 
                     index = ['Trauma', 'Urgent', 'Emergency']
                   )
df2.plot.pie(y='Type of Admission', figsize=(7,7), autopct='%1.1f%%')

# %%
df['Age'].value_counts()
# Out:
# 31-40     220
# 41-50     214
# 51-60     162
# 61-70     133
# 71-80     124
# 21-30      63
# 81-90      51
# 20-Nov     27
# 0-10        6
# Name: Age, dtype: int64

# %%
type_counts = df['Age'].value_counts()
df2 = pd.DataFrame({'Age': type_counts}, 
                     index = ['0-10', '20-Nov', '31-40', '41-50', '51-60', '61-70', '71-80', '81-90']
                   )
df2.plot.pie(y='Age', figsize=(7,7), autopct='%1.1f%%')

# %%
# Age group of 31-40 and 41-50 suffers from more diseases.

# %%
type_counts = df['Stay'].value_counts()
df2 = pd.DataFrame({'Stay': type_counts}, 
                     index = ['0-10', '20-Nov', '21-30', '31-40', '41-50', '51-60', '61-70', '71-80', '81-90', '91-100', 'More than 100 Days']
                   )
df2.plot.pie(y='Stay', figsize=(7,7), autopct='%1.1f%%')

# %%
# More patients have length of stay of 21-30 days.
# Out:
# 21-30                 298
# 20-Nov                182
# 31-40                 182
# 51-60                 124
# 0-10                   65
# 41-50                  46
# 71-80                  40
# 81-90                  25
# More than 100 Days     22
# 91-100                  8
# 61-70                   8
# Name: Stay, dtype: int64

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(10,10))
ax = sns.countplot(x='Department', data=df)

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(10,10))
ax = sns.countplot(x='Severity of Illness', data=df)
plt.gca().invert_xaxis()

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(10,10))
ax = sns.countplot(x='Type of Admission', data=df)

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(10,10))
df_sorted= df.sort_values('Age')
ax = sns.countplot(x='Age', data=df_sorted)

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(10,10))
ax = sns.countplot(x='Stay', data=df)

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(10,10))
df_sorted= df.sort_values('Stay')
ax = sns.countplot(x='Stay', data=df_sorted)

# %%
df_sorted
# Out:
#      case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0          1              8                  c                   3
# 147      148             23                  a                   6
# 60        61             31                  c                   3
# 148      149             23                  a                   6
# 970      971              6                  a                   6
# ..       ...            ...                ...                 ...
# 960      961             19                  a                   7
# 961      962             19                  a                   7
# 868      869              9                  d                   5
# 679      680             12                  a                   9
# 950      951             23                  a                   6
#
#     Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                      Z                                  3  radiotherapy
# ...

# %%
from sklearn.preprocessing import LabelEncoder
df_label=df.apply(LabelEncoder().fit_transform)

# %%
df_label
# Out:
#      case_id  Hospital_code  Hospital_type_code  City_Code_Hospital  \
# 0          0              7                   2                   2
# 1          1              1                   2                   4
# 2          2              9                   4                   0
# 3          3             25                   1                   1
# 4          4             25                   1                   1
# ..       ...            ...                 ...                 ...
# 995      995              3                   0                   3
# 996      996             22                   0                   5
# 997      997             13                   0                   0
# 998      998             12                   0                   4
# 999      999              7                   2                   2
#
#      Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                       2                                  2           3
# ...

# %%
# From here now, i correlate two variables using different plots.

# %%
x = df['Available Extra Rooms in Hospital']
df_sorted= df.sort_values('Stay')
y = df_sorted['Stay']
z = df_label['Age']/40
colors = np.random.rand(1000) 
plt.title('Available Extra Rooms in Hospital vs Stay with respect to Age')
plt.xlabel('Available Extra Rooms in Hospital')
plt.ylabel('Stay')
plt.scatter(x, y, s=z*3000,c=colors)
plt.gca().invert_yaxis()
scatter = plt.scatter(x, y, s=z*3000,c=colors)
ax = scatter.axes
ax.invert_yaxis()
plt.show()

# %%
# In Bed Grade vs Stay with respect to Admission deposit. 
# The quality of bed grade is directly proportional to Admission Deposit and length of stay.

# %%
x = df['Department']
df_sorted= df.sort_values('Stay')
y = df_sorted['Stay']
z = df_label['Age']/40
colors = np.random.rand(1000) 
plt.title('Department vs Stay with respect to Age')
plt.xlabel('Department')
plt.ylabel('Stay')
plt.scatter(x, y, s=z*3000,c=colors)
scatter = plt.scatter(x, y, s=z*3000,c=colors)
ax = scatter.axes
plt.gca().invert_yaxis()
ax.invert_yaxis()
plt.show()

# %%
x = df['Bed Grade']
df_sorted= df.sort_values('Stay')
y = df_sorted['Stay']
z = df_label['Age']/40
colors = np.random.rand(1000) 
plt.title('Bed Grade vs Stay with respect to Age')
plt.xlabel('Bed Grade')
plt.ylabel('Stay')
plt.scatter(x, y, s=z*3000,c=colors)
scatter = plt.scatter(x, y, s=z*3000,c=colors)
plt.show()

# %%
x = df['Type of Admission']
df_sorted= df.sort_values('Stay')
y = df_sorted['Stay']
z = df_label['Age']/40
colors = np.random.rand(1000) 
plt.title('Type of Admission vs Stay with respect to Age')
plt.xlabel('Type of Admission')
plt.ylabel('Stay')
plt.scatter(x, y, s=z*3000,c=colors)
scatter = plt.scatter(x, y, s=z*3000,c=colors)
plt.show()

# %%
x = df['Visitors with Patient']
df_sorted= df.sort_values('Stay')
y = df_sorted['Stay']
z = df_label['Age']/40
colors = np.random.rand(1000) 
plt.title('Visitors with Patient vs Stay with respect to Age')
plt.xlabel('Visitors with Patient')
plt.ylabel('Stay')
plt.scatter(x, y, s=z*3000,c=colors)
scatter = plt.scatter(x, y, s=z*3000,c=colors)
plt.show()

# %%
x = df['Admission_Deposit']
df_sorted= df.sort_values('Stay')
y = df_sorted['Stay']
z = df_label['Age']/400
colors = np.random.rand(1000) 
plt.title('Admission_Deposit vs Stay with respect to Age')
plt.xlabel('Admission_Deposit')
plt.ylabel('Stay')
plt.scatter(x, y, s=z*3000,c=colors)
scatter = plt.scatter(x, y, s=z*3000,c=colors)
plt.show()

# %%
# So i calculate the correlation between categorical varaible for 5 columns as order below,

# Department
# Type of Admission
# Severity of Illness
# Age
# Stay

# %%
# I correlate between categorical variables as below,

# Department vs Stay
# Type of Admission vs Stay
# Severity of Illness vs Stay
# Age vs Stay

# %%
dft1=pd.crosstab(df['Department'], df['Stay'])
dft1
# Out:
# Stay                0-10  20-Nov  21-30  31-40  41-50  51-60  61-70  71-80  \
# Department
# TB & Chest disease     5       7     10      2      0      1      0      2
# anesthesia             3      26     25     15      4      4      1      5
# gynecology            47     127    232    148     36    104      7     28
# radiotherapy          10      22     31     17      6     15      0      5
#
# Stay                81-90  91-100  More than 100 Days
# Department
# TB & Chest disease      0       0                   1
# anesthesia              2       1                   6
# gynecology             20       7                  13
# radiotherapy            3       0                   2

# %%
chiStats = stats.chi2_contingency(observed= dft1)

# %%
print(chiStats[1], chiStats[2])
# Out:
# 0.07001535514576372 30

# %%
alpha = 0.05
critical_value = crit = stats.chi2.ppf(q = 1 - alpha,
                      df = chiStats[2])

# %%
observed_chi_val = chiStats[0]

# %%
print(observed_chi_val, critical_value)
# Out:
# 42.111496150675 43.77297182574219

# %%
if observed_chi_val <= critical_value:
    print ('Null hypothesis cannot be rejected (variables are independent)')
else:
    print ('Null hypothesis can be rejected (variables are dependent)')
# Out:
# Null hypothesis cannot be rejected (variables are independent)

# %%
dft2=pd.crosstab(df['Type of Admission'], df['Stay'])
dft2
# Out:
# Stay               0-10  20-Nov  21-30  31-40  41-50  51-60  61-70  71-80  \
# Type of Admission
# Emergency            40      79     98     63     17     55      4     13
# Trauma               18      79    154     93     27     59      4     20
# Urgent                7      24     46     26      2     10      0      7
#
# Stay               81-90  91-100  More than 100 Days
# Type of Admission
# Emergency             11       3                   7
# Trauma                11       5                  14
# Urgent                 3       0                   1

# %%
chiStats = stats.chi2_contingency(observed= dft2)

# %%
print(chiStats[1], chiStats[2])
# Out:
# 0.013969630009040663 20

# %%
alpha = 0.05
critical_value = crit = stats.chi2.ppf(q = 1 - alpha,
                      df = chiStats[2])

# %%
observed_chi_val = chiStats[0]

# %%
print(observed_chi_val, critical_value)
# Out:
# 36.354380275339174 31.410432844230918

# %%
if observed_chi_val <= critical_value:
    print ('Null hypothesis cannot be rejected (variables are independent)')
else:
    print ('Null hypothesis can be rejected (variables are dependent)')
# Out:
# Null hypothesis can be rejected (variables are dependent)

# %%
dft3=pd.crosstab(df['Severity of Illness'], df['Stay'])
dft3
# Out:
# Stay                 0-10  20-Nov  21-30  31-40  41-50  51-60  61-70  71-80  \
# Severity of Illness
# Extreme                15      48     85     74     20     47      0     11
# Minor                  10      28     31     18      2      6      0      1
# Moderate               40     106    182     90     24     71      8     28
#
# Stay                 81-90  91-100  More than 100 Days
# Severity of Illness
# Extreme                 10       6                  10
# Minor                    0       0                   0
# Moderate                15       2                  12

# %%
chiStats = stats.chi2_contingency(observed= dft3)

# %%
print(chiStats[1], chiStats[2])
# Out:
# 0.0002094380736886651 20

# %%
alpha = 0.05
critical_value = crit = stats.chi2.ppf(q = 1 - alpha,
                      df = chiStats[2])

# %%
observed_chi_val = chiStats[0]

# %%
print(observed_chi_val, critical_value)
# Out:
# 50.16943271441498 31.410432844230918

# %%
if observed_chi_val <= critical_value:
    print ('Null hypothesis cannot be rejected (variables are independent)')
else:
    print ('Null hypothesis can be rejected (variables are dependent)')
# Out:
# Null hypothesis can be rejected (variables are dependent)

# %%
dft4=pd.crosstab(df['Age'], df['Stay'])
dft4
# Out:
# Stay    0-10  20-Nov  21-30  31-40  41-50  51-60  61-70  71-80  81-90  91-100  \
# Age
# 0-10       1       2      2      0      0      1      0      0      0       0
# 20-Nov     5       3     10      8      0      1      0      0      0       0
# 21-30      7      20     13     16      3      1      0      0      1       0
# 31-40     14      42     76     31      9     38      1      5      1       1
# 41-50      7      26     71     49      7     25      2     14      4       2
# 51-60     12      37     44     18      9     19      2      7      5       4
# 61-70      5      27     41     28      8     13      1      4      5       0
# 71-80     10      16     29     22      8     20      2      7      5       0
# 81-90      4       9     12     10      2      6      0      3      4       1
#
# Stay    More than 100 Days
# Age
# 0-10                     0
# 20-Nov                   0
# 21-30                    2
# 31-40                    2
# 41-50                    7
# ...

# %%
chiStats = stats.chi2_contingency(observed= dft4)

# %%
print(chiStats[1], chiStats[2])
# Out:
# 0.004491130469072165 80

# %%
alpha = 0.05
critical_value = crit = stats.chi2.ppf(q = 1 - alpha,
                      df = chiStats[2])

# %%
observed_chi_val = chiStats[0]

# %%
print(observed_chi_val, critical_value)
# Out:
# 116.91919865203653 101.87947396543588

# %%
if observed_chi_val <= critical_value:
    print ('Null hypothesis cannot be rejected (variables are independent)')
else:
    print ('Null hypothesis can be rejected (variables are dependent)')
# Out:
# Null hypothesis can be rejected (variables are dependent)

# %%
chisqtable = {'Column Attributes':  ['Department', 'Type of Admission', 'Severity of Illness', 'Age'],
        'Relation with Stay variable': ['Independent', 'Dependent', 'Dependent', 'Dependent'],
        }
dfchi = pd.DataFrame (chisqtable, columns = ['Column Attributes','Relation with Stay variable'])
dfchi
# Out:
#      Column Attributes Relation with Stay variable
# 0           Department                 Independent
# 1    Type of Admission                   Dependent
# 2  Severity of Illness                   Dependent
# 3                  Age                   Dependent

# %%
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.tools import FigureFactory as FF

import numpy as np
import pandas as pd
import scipy

# %%
import numpy as np
from scipy import stats
N = 10000
a = df_label['Bed Grade']
b = df_label['Stay']
var_a = a.var(ddof=1)
var_b = b.var(ddof=1)
s = np.sqrt((var_a + var_b)/2.0)
t = (a.mean() - b.mean())/(s*np.sqrt(2.0/N))
df = len(a) + len(b) - 2.0
p = stats.t.cdf(t,df=df)
print("t = " + str(t))
print("p = " + str(2.0*p))
# Out:
# t = -62.3466127096271
# p = 0.0

# %%
df=pd.read_csv(r'healthdata.csv')

# %%
df
# Out:
#      case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0          1              8                  c                   3
# 1          2              2                  c                   5
# 2          3             10                  e                   1
# 3          4             26                  b                   2
# 4          5             26                  b                   2
# ..       ...            ...                ...                 ...
# 995      996              4                  a                   4
# 996      997             23                  a                   6
# 997      998             14                  a                   1
# 998      999             13                  a                   5
# 999     1000              8                  c                   3
#
#     Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                      Z                                  3  radiotherapy
# ...

# %%
import numpy as np
from scipy import stats
N = 10000
a = df_label['Available Extra Rooms in Hospital']
b = df_label['Stay']
var_a = a.var(ddof=1)
var_b = b.var(ddof=1)
s = np.sqrt((var_a + var_b)/2.0)
t = (a.mean() - b.mean())/(s*np.sqrt(2.0/N))
df = len(a) + len(b) - 2.0
p = stats.t.cdf(t,df=df)
print("t = " + str(t))
print("p = " + str(2.0*p))
# Out:
# t = -28.64997441626293
# p = 1.5718926572936218e-151

# %%
import numpy as np
from scipy import stats
N = 10000
a = df_label['Visitors with Patient']
b = df_label['Stay']
var_a = a.var(ddof=1)
var_b = b.var(ddof=1)
s = np.sqrt((var_a + var_b)/2.0)
t = (a.mean() - b.mean())/(s*np.sqrt(2.0/N))
df = len(a) + len(b) - 2.0
p = stats.t.cdf(t,df=df)
print("t = " + str(t))
print("p = " + str(2.0*p))
# Out:
# t = -28.334478916370912
# p = 9.458829416920632e-149

# %%
import numpy as np
from scipy import stats
N = 10000
a = df_label['Admission_Deposit']
b = df_label['Stay']
var_a = a.var(ddof=1)
var_b = b.var(ddof=1)
s = np.sqrt((var_a + var_b)/2.0)
t = (a.mean() - b.mean())/(s*np.sqrt(2.0/N))
df = len(a) + len(b) - 2.0
p = stats.t.cdf(t,df=df)
print("t = " + str(t))
print("p = " + str(2.0*p))
# Out:
# t = 174.40323821069256
# p = 2.0
