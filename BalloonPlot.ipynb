# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\ghpu\JupyterNotebook\datasets\healthcare\healthdata.csv")

# %%
df
# Out:
#      case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0          1              8                  c                   3
# 1          2              2                  c                   5
# 2          3             10                  e                   1
# 3          4             26                  b                   2
# 4          5             26                  b                   2
# ..       ...            ...                ...                 ...
# 995      996              4                  a                   4
# 996      997             23                  a                   6
# 997      998             14                  a                   1
# 998      999             13                  a                   5
# 999     1000              8                  c                   3
#
#     Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                      Z                                  3  radiotherapy
# ...

# %%
df["Stay"] = pd.Categorical(df["Stay"], 
                      categories=["0-10","20-Nov","21-30","31-40", "41-50", "51-60", "61-70", "71-80", "81-90", "91-100", "More than 100 Days"],
                      ordered=True)
df["Stay"]=df["Stay"].cat.codes

# %%
df['Stay'] = df['Stay'].replace({0 : '0-10', 1 : '11-20', 2 : '21-30', 3 : '31-40', 4 : '41-50', 5 : '51-60', 6 : '61-70', 7 : '71-80', 8 : '81-90', 9 : '91-100', 10 : 'More than 100'})

# %%
df['Stay']=sorted(df['Stay'])

# %%
df['Stay'].value_counts()
# Out:
# 21-30            298
# 31-40            182
# 11-20            182
# 51-60            124
# 0-10              65
# 41-50             46
# 71-80             40
# 81-90             25
# More than 100     22
# 61-70              8
# 91-100             8
# Name: Stay, dtype: int64

# %%
df["Stay_Labels"] = pd.Categorical(df["Stay"], 
                      categories=["0-10","11-20","21-30","31-40", "41-50", "51-60", "61-70", "71-80", "81-90", "91-100", "More than 100"],
                      ordered=True)
df["Stay_Labels"]=df["Stay_Labels"].cat.codes

# %%
df['Stay_Labels'].value_counts()
# Out:
# 2     298
# 3     182
# 1     182
# 5     124
# 0      65
# 4      46
# 7      40
# 8      25
# 10     22
# 9       8
# 6       8
# Name: Stay_Labels, dtype: int64

# %%
df["Age"] = pd.Categorical(df["Age"], 
                      categories=["1-10","20-Nov","21-30","31-40", "41-50", "51-60", "61-70", "71-80", "81-90", "91-100"],
                      ordered=True)
df["Age"]=df["Age"].cat.codes

# %%
df['Age'] = df['Age'].replace({0 : '1-10', 1 : '11-20', 2 : '21-30', 3 : '31-40', 4 : '41-50', 5 : '51-60', 6 : '61-70', 7 : '71-80', 8 : '81-90', 9 : '91-100'})

# %%
df['Age']
# Out:
# 0      51-60
# 1      51-60
# 2      51-60
# 3      51-60
# 4      51-60
#        ...
# 995    41-50
# 996    41-50
# 997    41-50
# 998    51-60
# 999    51-60
# Name: Age, Length: 1000, dtype: object

# %%
#df['Age']=sorted(df['Age'])

# %%
df["Age_Labels"] = pd.Categorical(df["Age"], 
                      categories=["0-10","11-20","21-30","31-40", "41-50", "51-60", "61-70", "71-80", "81-90", "91-100"],
                      ordered=True)
df["Age_Labels"]=df["Age_Labels"].cat.codes

# %%
df["Severity of Illness"] = pd.Categorical(df["Severity of Illness"], 
                      categories=["Minor","Moderate","Extreme"],
                      ordered=True)
df["Severity of Illness"]=df["Severity of Illness"].cat.codes

# %%
df['Severity of Illness'] = df['Severity of Illness'].replace({0 : 'Minor', 1 : 'Moderate', 2 : 'Extreme'})

# %%
#df['Severity of Illness']=sorted(df['Severity of Illness'])

# %%
df["Severity of Illness_Labels"] = pd.Categorical(df["Severity of Illness"], 
                      categories=["Minor","Moderate","Extreme"],
                      ordered=True)
df["Severity of Illness_Labels"]=df["Severity of Illness_Labels"].cat.codes

# %%
illorder = ['Minor','Moderate','Extreme']
df['Severity of Illness'] = pd.Categorical(df['Severity of Illness'], categories = illorder , ordered = True)

# %%
stayorder = ["0-10","11-20","21-30","31-40", "41-50", "51-60", "61-70", "71-80", "81-90", "91-100", "More than 100"]
df['Stay'] = pd.Categorical(df['Stay'], categories = stayorder , ordered = True)

# %%
df.drop(columns=['case_id', 'Hospital_code', 'Hospital_type_code' , 'City_Code_Hospital', 'Hospital_region_code', 'Ward_Type', 'Ward_Facility_Code', 'patientid', 'City_Code_Patient'])
# Out:
#      Available Extra Rooms in Hospital    Department  Bed Grade  \
# 0                                    3  radiotherapy        2.0
# 1                                    2  radiotherapy        2.0
# 2                                    2    anesthesia        2.0
# 3                                    2  radiotherapy        2.0
# 4                                    2  radiotherapy        2.0
# ..                                 ...           ...        ...
# 995                                  2    anesthesia        4.0
# 996                                  4    gynecology        4.0
# 997                                  4    gynecology        2.0
# 998                                  4    gynecology        4.0
# 999                                  4    gynecology        3.0
#
#     Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0           Emergency             Extreme                      2  51-60
# ...

# %%
plt.gca().invert_yaxis()
x = df['Available Extra Rooms in Hospital']
y = df['Stay']
z = df['Age_Labels']/40
colors = np.random.rand(1000) 
plt.title('Available Extra Rooms in Hospital vs Stay with respect to Age')
plt.xlabel('Available Extra Rooms in Hospital')
plt.ylabel('Stay')
plt.scatter(x, y, s=z*3000,c=colors)
scatter = plt.scatter(x, y, s=z*3000,c=colors)
ax = scatter.axes
ax.invert_yaxis()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\collections.py:885: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
plt.gca().invert_yaxis()
x = df['Department']
y = df['Stay']
z = df['Age_Labels']/40
colors = np.random.rand(1000) 
plt.title('Department vs Stay with respect to Age')
plt.xlabel('Department')
plt.ylabel('Stay')
plt.scatter(x, y, s=z*3000,c=colors)
scatter = plt.scatter(x, y, s=z*3000,c=colors)
ax = scatter.axes
ax.invert_yaxis()
plt.show()

# %%
plt.gca().invert_yaxis()
x = df['Bed Grade']
y = df['Stay']
z = df['Age_Labels']/40
colors = np.random.rand(1000) 
plt.title('Bed Grade vs Stay with respect to Age')
plt.xlabel('Bed Grade')
plt.ylabel('Stay')
plt.scatter(x, y, s=z*3000,c=colors)
scatter = plt.scatter(x, y, s=z*3000,c=colors)
ax = scatter.axes
ax.invert_yaxis()
plt.show()

# %%
plt.gca().invert_yaxis()
x = df['Type of Admission']
y = df['Stay']
z = df['Age_Labels']/40
colors = np.random.rand(1000) 
plt.title('Type of Admission vs Stay with respect to Age')
plt.xlabel('Type of Admission')
plt.ylabel('Stay')
plt.scatter(x, y, s=z*3000,c=colors)
scatter = plt.scatter(x, y, s=z*3000,c=colors)
ax = scatter.axes
ax.invert_yaxis()
plt.show()

# %%
plt.gca().invert_yaxis()
x = df['Severity of Illness']
y = df['Stay']
z = df['Age_Labels']/40
colors = np.random.rand(1000) 
plt.title('Severity of Illness vs Stay with respect to Age')
plt.xlabel('Severity of Illness')
plt.ylabel('Stay')
plt.scatter(x, y, s=z*3000,c=colors)
scatter = plt.scatter(x, y, s=z*3000,c=colors)
ax = scatter.axes
ax.invert_yaxis()
plt.show()

# %%
plt.gca().invert_yaxis()
x = df['Visitors with Patient']
y = df['Stay']
z = df['Age_Labels']/40
colors = np.random.rand(1000) 
plt.title('Visitors with Patient vs Stay with respect to Age')
plt.xlabel('Visitors with Patient')
plt.ylabel('Stay')
plt.scatter(x, y, s=z*3000,c=colors)
scatter = plt.scatter(x, y, s=z*3000,c=colors)
ax = scatter.axes
ax.invert_yaxis()
plt.show()

# %%
plt.gca().invert_yaxis()
x = df['Age_Labels']
y = df['Stay']
z = df['Age_Labels']/40
colors = np.random.rand(1000) 
plt.title('Age vs Stay with respect to Age')
plt.xlabel('Age')
plt.ylabel('Stay')
plt.scatter(x, y, s=z*3000,c=colors)
scatter = plt.scatter(x, y, s=z*3000,c=colors)
ax = scatter.axes
ax.invert_yaxis()
plt.show()

# %%
plt.gca().invert_yaxis()
x = df['Admission_Deposit']
y = df['Stay']
z = df['Age_Labels']/40
colors = np.random.rand(1000) 
plt.title('Admission_Deposit vs Stay with respect to Age')
plt.xlabel('Admission_Deposit')
plt.ylabel('Stay')
plt.scatter(x, y, s=z*3000,c=colors)
scatter = plt.scatter(x, y, s=z*3000,c=colors)
ax = scatter.axes
ax.invert_yaxis()
plt.show()
