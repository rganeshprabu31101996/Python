# %%
import pandas as pd

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
#Get the input train dataset from directory of more than 3 lakhs dataset
train = r"C:\Users\ghpu\JupyterNotebook\datasets\healthcare\train.csv"
traindata=pd.read_csv(train)

# %%
traindata
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0             1              8                  c                   3
# 1             2              2                  c                   5
# 2             3             10                  e                   1
# 3             4             26                  b                   2
# 4             5             26                  b                   2
# ...         ...            ...                ...                 ...
# 318433   318434              6                  a                   6
# 318434   318435             24                  a                   1
# 318435   318436              7                  a                   4
# 318436   318437             11                  b                   2
# 318437   318438             19                  a                   7
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# ...

# %%
n = 318439
s = 1000
skip = sorted(random.sample(range(n),n-s))
#Random Sample of 1000 rows
rd1000 = pd.read_csv(train, skiprows=skip)

# %%
rd1000.head()
# Out:
#      39  32  f  9  Y  2  radiotherapy  S  B  3.0  115513   7.0  Emergency  \
# 0   290  32  f  9  Y  4    gynecology  S  B  2.0   27075  15.0  Emergency
# 1   713  19  a  7  Y  6  radiotherapy  Q  C  2.0  130669   8.0  Emergency
# 2   899  26  b  2  Y  4    gynecology  Q  D  2.0   37534   5.0  Emergency
# 3  1065  26  b  2  Y  4    gynecology  Q  D  1.0   62491   8.0     Trauma
# 4  1400   5  a  1  X  3    anesthesia  Q  E  2.0  109671   1.0     Trauma
#
#       Minor  2.1  71-80  4971.0  11-20
# 0   Extreme    2  21-30  5405.0  31-40
# 1   Extreme    4  81-90  3634.0  21-30
# 2  Moderate    4  41-50  4150.0  41-50
# 3   Extreme    3  61-70  4604.0  21-30
# 4  Moderate    4  51-60  4470.0  31-40

# %%
rd1000.tail()
# Out:
#          39  32  f  9  Y  2        radiotherapy  S  B  3.0  115513  7.0  \
# 994  317019  27  a  7  Y  4          gynecology  R  C  4.0   11898  8.0
# 995  317300  26  b  2  Y  2          anesthesia  R  D  3.0   99338  7.0
# 996  317685  26  b  2  Y  3          gynecology  R  D  1.0   80669  4.0
# 997  317813   6  a  6  X  4          gynecology  R  F  2.0    9084  2.0
# 998  318372   7  a  4  X  3  TB & Chest disease  R  F  4.0   17015  8.0
#
#     Emergency     Minor  2.1  71-80  4971.0  11-20
# 994    Trauma  Moderate    3  31-40  7915.0  21-30
# 995    Urgent  Moderate    2  41-50  5087.0  11-20
# 996    Urgent  Moderate    2  31-40  5317.0  11-20
# 997    Urgent     Minor    2  11-20  5350.0  11-20
# 998    Trauma  Moderate    3  51-60  5899.0  11-20

# %%
#Column header is not arranged properly
rd1000.to_csv(r'C:\Users\ghpu\JupyterNotebook\datasets\healthcare\randomsample.csv', index = False)

# %%
oldsample=pd.read_csv(r"C:\Users\ghpu\JupyterNotebook\datasets\healthcare\randomsample.csv", sep = ',')

# %%
oldsample.head()
# Out:
#      39  32  f  9  Y  2  radiotherapy  S  B  3.0  115513   7.0  Emergency  \
# 0   290  32  f  9  Y  4    gynecology  S  B  2.0   27075  15.0  Emergency
# 1   713  19  a  7  Y  6  radiotherapy  Q  C  2.0  130669   8.0  Emergency
# 2   899  26  b  2  Y  4    gynecology  Q  D  2.0   37534   5.0  Emergency
# 3  1065  26  b  2  Y  4    gynecology  Q  D  1.0   62491   8.0     Trauma
# 4  1400   5  a  1  X  3    anesthesia  Q  E  2.0  109671   1.0     Trauma
#
#       Minor  2.1  71-80  4971.0  11-20
# 0   Extreme    2  21-30  5405.0  31-40
# 1   Extreme    4  81-90  3634.0  21-30
# 2  Moderate    4  41-50  4150.0  41-50
# 3   Extreme    3  61-70  4604.0  21-30
# 4  Moderate    4  51-60  4470.0  31-40

# %%
#Adding column name to the random sample dataset
col_Names=[r"case_id", "Hospital_code", "Hospital_type_code", "City_Code_Hospital", "Hospital_region_code", "Available Extra Rooms in Hospital", "Department", "Ward_Type", "Ward_Facility_Code", "Bed Grade", "patientid","City_Code_Patient","Type of Admission","Severity of Illness","Visitors with Patient", "Age", "Admission_Deposit", "Stay"
]
sample= pd.read_csv(r"C:\Users\ghpu\JupyterNotebook\datasets\healthcare\randomsample.csv",names=col_Names)

# %%
sample.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0       39             32                  f                   9
# 1      290             32                  f                   9
# 2      713             19                  a                   7
# 3      899             26                  b                   2
# 4     1065             26                  b                   2
#
#   Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                    Y                                  2  radiotherapy
# 1                    Y                                  4    gynecology
# 2                    Y                                  6  radiotherapy
# 3                    Y                                  4    gynecology
# 4                    Y                                  4    gynecology
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# ...

# %%
sample.tail()
# Out:
#      case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 995   317019             27                  a                   7
# 996   317300             26                  b                   2
# 997   317685             26                  b                   2
# 998   317813              6                  a                   6
# 999   318372              7                  a                   4
#
#     Hospital_region_code  Available Extra Rooms in Hospital  \
# 995                    Y                                  4
# 996                    Y                                  2
# 997                    Y                                  3
# 998                    X                                  4
# 999                    X                                  3
#
#              Department Ward_Type Ward_Facility_Code  Bed Grade  patientid  \
# 995          gynecology         R                  C        4.0      11898
# ...

# %%
sample
# Out:
#      case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0         39             32                  f                   9
# 1        290             32                  f                   9
# 2        713             19                  a                   7
# 3        899             26                  b                   2
# 4       1065             26                  b                   2
# ..       ...            ...                ...                 ...
# 995   317019             27                  a                   7
# 996   317300             26                  b                   2
# 997   317685             26                  b                   2
# 998   317813              6                  a                   6
# 999   318372              7                  a                   4
#
#     Hospital_region_code  Available Extra Rooms in Hospital  \
# 0                      Y                                  2
# ...

# %%
print(sample.count((0)))
# Out:
# case_id                              1000
# Hospital_code                        1000
# Hospital_type_code                   1000
# City_Code_Hospital                   1000
# Hospital_region_code                 1000
# Available Extra Rooms in Hospital    1000
# Department                           1000
# Ward_Type                            1000
# Ward_Facility_Code                   1000
# Bed Grade                            1000
# patientid                            1000
# City_Code_Patient                     986
# Type of Admission                    1000
# Severity of Illness                  1000
# Visitors with Patient                1000
# Age                                  1000
# Admission_Deposit                    1000
# Stay                                 1000
# dtype: int64

# %%
print(sample.shape)
# Out:
# (1000, 18)

# %%
import seaborn as sns
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()

# %%
type(sample)
# Out:
# pandas.core.frame.DataFrame

# %%
sample.size
# Out:
# 18000

# %%
sns.heatmap(sample.corr(), annot=True, cmap="YlGnBu")
plt.show()

# %%
X= sample.iloc[ : , :-1].values
y= sample.iloc[ : , -1].values

# %%
type(X)
# Out:
# numpy.ndarray

# %%
#independent variable
print(X)
# Out:
# [[39 32 'f' ... 2.1 '71-80' 4971.0]
#  [290 32 'f' ... 2.0 '21-30' 5405.0]
#  [713 19 'a' ... 4.0 '81-90' 3634.0]
#  ...
#  [317685 26 'b' ... 2.0 '31-40' 5317.0]
#  [317813 6 'a' ... 2.0 '11-20' 5350.0]
#  [318372 7 'a' ... 3.0 '51-60' 5899.0]]

# %%
#Dependent Vaiable
print(y)
# Out:
# ['11-20' '31-40' '21-30' '41-50' '21-30' '31-40' '31-40' '51-60' '31-40'
#  '41-50' '51-60' '0-10' '31-40' '21-30' '41-50' '51-60' '31-40' '41-50'
#  '21-30' '11-20' '11-20' '21-30' '11-20' '21-30' '11-20' '51-60' '11-20'
#  '31-40' '11-20' '11-20' '31-40' '21-30' '91-100' '31-40' '51-60' '31-40'
#  '21-30' '0-10' '21-30' '31-40' '31-40' '31-40' '51-60' '31-40' '51-60'
#  'More than 100 Days' 'More than 100 Days' '21-30' '51-60' '31-40' '21-30'
#  '21-30' '21-30' '51-60' '11-20' '0-10' '21-30' '51-60' '21-30' '31-40'
#  '31-40' '11-20' '41-50' '21-30' '21-30' '41-50' '81-90' '11-20' '11-20'
#  '11-20' '71-80' '51-60' '31-40' '21-30' '11-20' '21-30' '21-30' '21-30'
#  '81-90' '81-90' '21-30' '31-40' '51-60' '21-30' '21-30' '31-40' '71-80'
#  '51-60' '21-30' '21-30' '21-30' '0-10' '11-20' '31-40' '21-30' '11-20'
#  '31-40' '11-20' '11-20' '21-30' '11-20' '21-30' '21-30' '31-40' '41-50'
#  '51-60' '0-10' '31-40' '21-30' '51-60' '21-30' '0-10' '41-50' '11-20'
# ...

# %%
sample
# Out:
#      case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0         39             32                  f                   9
# 1        290             32                  f                   9
# 2        713             19                  a                   7
# 3        899             26                  b                   2
# 4       1065             26                  b                   2
# ..       ...            ...                ...                 ...
# 995   317019             27                  a                   7
# 996   317300             26                  b                   2
# 997   317685             26                  b                   2
# 998   317813              6                  a                   6
# 999   318372              7                  a                   4
#
#     Hospital_region_code  Available Extra Rooms in Hospital  \
# 0                      Y                                  2
# ...

# %%
df=traindata

# %%
#Missing values for each of the variable

df.isnull().sum(axis = 0)
# Out:
# case_id                                 0
# Hospital_code                           0
# Hospital_type_code                      0
# City_Code_Hospital                      0
# Hospital_region_code                    0
# Available Extra Rooms in Hospital       0
# Department                              0
# Ward_Type                               0
# Ward_Facility_Code                      0
# Bed Grade                             113
# patientid                               0
# City_Code_Patient                    4532
# Type of Admission                       0
# Severity of Illness                     0
# Visitors with Patient                   0
# Age                                     0
# Admission_Deposit                       0
# Stay                                    0
# dtype: int64

# %%
df.isnull().sum(axis = 1)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 318433    0
# 318434    0
# 318435    0
# 318436    0
# 318437    0
# Length: 318438, dtype: int64

# %%
mean1 = df['case_id'].mean()
max1 = df['case_id'].max()
min1 = df['case_id'].min()
count1 = df['case_id'].count()
median1 = df['case_id'].median() 
mode1=df['case_id'].mode()
std1 = df['case_id'].std() 
var1 = df['case_id'].var()

# %%
print ('Mean: ' + str(mean1))
print ('Median: ' + str(median1))
print ('Mode: ' + str(mode1))
print('Standard deviation: ' +str(std1))
print("Variance: " +str(var1))
print("Range: from " +str(min1))
print("to  " +str(max1))
# Out:
# Mean: 159219.5
# Median: 159219.5
# Mode: 0              1
# 1              2
# 2              3
# 3              4
# 4              5
#            ...
# 318433    318434
# 318434    318435
# 318435    318436
# 318436    318437
# 318437    318438
# Length: 318438, dtype: int64
# Standard deviation: 91925.27684747313
# Variance: 8450256523.484579
# Range: from 1
# to  318438

# %%
mean2 = df['Hospital_code'].mean()
max2 = df['Hospital_code'].max()
min2 = df['Hospital_code'].min()
count2 = df['Hospital_code'].count()
median2 = df['Hospital_code'].median() 
mode2=df['Hospital_code'].mode()
std2 = df['Hospital_code'].std() 
var2 = df['Hospital_code'].var()

# %%
print ('Mean: ' + str(mean2))
print ('Median: ' + str(median2))
print ('Mode: ' + str(mode2))
print('Standard deviation: ' +str(std2))
print("Variance: " +str(var2))
print("Range: from " +str(min2))
print("to  " +str(max2))
# Out:
# Mean: 18.318840716246175
# Median: 19.0
# Mode: 0    26
# dtype: int64
# Standard deviation: 8.633754885792921
# Variance: 74.54172342795314
# Range: from 1
# to  32

# %%
mean3 = df['Available Extra Rooms in Hospital'].mean()
max3 = df['Available Extra Rooms in Hospital'].max()
min3 = df['Available Extra Rooms in Hospital'].min()
count3 = df['Available Extra Rooms in Hospital'].count()
median3 = df['Available Extra Rooms in Hospital'].median() 
mode3=df['Available Extra Rooms in Hospital'].mode()
std3 = df['Available Extra Rooms in Hospital'].std() 
var3 = df['Available Extra Rooms in Hospital'].var()

# %%
print ('Mean: ' + str(mean3))
print ('Median: ' + str(median3))
print ('Mode: ' + str(mode3))
print('Standard deviation: ' +str(std3))
print("Variance: " +str(var3))
print("Range: from " +str(min3))
print("to  " +str(max3))
# Out:
# Mean: 3.1976271676119055
# Median: 3.0
# Mode: 0    2
# dtype: int64
# Standard deviation: 1.1681714278588335
# Variance: 1.364624484865746
# Range: from 0
# to  24

# %%
mean4 = df['Bed Grade'].mean()
max4 = df['Bed Grade'].max()
min4 = df['Bed Grade'].min()
count4 = df['Bed Grade'].count()
median4 = df['Bed Grade'].median() 
mode4=df['Bed Grade'].mode()
std4 = df['Bed Grade'].std() 
var4 = df['Bed Grade'].var()

# %%
print ('Mean: ' + str(mean4))
print ('Median: ' + str(median4))
print ('Mode: ' + str(mode4))
print('Standard deviation: ' +str(std4))
print("Variance: " +str(var4))
print("Range: from " +str(min4))
print("to  " +str(max4))
# Out:
# Mean: 2.625806958297338
# Median: 3.0
# Mode: 0    2.0
# dtype: float64
# Standard deviation: 0.873145804590605
# Variance: 0.7623835960741749
# Range: from 1.0
# to  4.0

# %%
mean5 = df['patientid'].mean()
max5 = df['patientid'].max()
min5 = df['patientid'].min()
count5 = df['patientid'].count()
median5 = df['patientid'].median() 
mode5=df['patientid'].mode()
std5 = df['patientid'].std() 
var5 = df['patientid'].var()

# %%
print ('Mean: ' + str(mean5))
print ('Median: ' + str(median5))
print ('Mode: ' + str(mode5))
print('Standard deviation: ' +str(std5))
print("Variance: " +str(var5))
print("Range: from " +str(min5))
print("to  " +str(max5))
# Out:
# Mean: 65747.57947229916
# Median: 65724.5
# Mode: 0    66714
# dtype: int64
# Standard deviation: 37979.93644002367
# Variance: 1442475571.9882374
# Range: from 1
# to  131624

# %%
mean6 = df['City_Code_Patient'].mean()
max6 = df['City_Code_Patient'].max()
min6 = df['City_Code_Patient'].min()
count6 = df['City_Code_Patient'].count()
median6 = df['City_Code_Patient'].median() 
mode6=df['City_Code_Patient'].mode()
std6 = df['City_Code_Patient'].std() 
var6 = df['City_Code_Patient'].var()

# %%
print ('Mean: ' + str(mean6))
print ('Median: ' + str(median6))
print ('Mode: ' + str(mode6))
print('Standard deviation: ' +str(std6))
print("Variance: " +str(var6))
print("Range: from " +str(min6))
print("to  " +str(max6))
# Out:
# Mean: 7.251858836721821
# Median: 8.0
# Mode: 0    8.0
# dtype: float64
# Standard deviation: 4.745265561142337
# Variance: 22.517545245763493
# Range: from 1.0
# to  38.0

# %%
mean7 = df['Visitors with Patient'].mean()
max7 = df['Visitors with Patient'].max()
min7 = df['Visitors with Patient'].min()
count7 = df['Visitors with Patient'].count()
median7 = df['Visitors with Patient'].median() 
mode7=df['Visitors with Patient'].mode()
std7 = df['Visitors with Patient'].std() 
var7 = df['Visitors with Patient'].var()

# %%
print ('Mean: ' + str(mean7))
print ('Median: ' + str(median7))
print ('Mode: ' + str(mode7))
print('Standard deviation: ' +str(std7))
print("Variance: " +str(var7))
print("Range: from " +str(min7))
print("to  " +str(max7))
# Out:
# Mean: 3.2840992595104854
# Median: 3.0
# Mode: 0    2
# dtype: int64
# Standard deviation: 1.7640613895571013
# Variance: 3.1119125861261314
# Range: from 0
# to  32

# %%
mean8 = df['Admission_Deposit'].mean()
max8 = df['Admission_Deposit'].max()
min8 = df['Admission_Deposit'].min()
count8 = df['Admission_Deposit'].count()
median8 = df['Admission_Deposit'].median() 
mode8=df['Admission_Deposit'].mode()
std8 = df['Admission_Deposit'].std() 
var8 = df['Admission_Deposit'].var()

# %%
print ('Mean: ' + str(mean8))
print ('Median: ' + str(median8))
print ('Mode: ' + str(mode8))
print('Standard deviation: ' +str(std8))
print("Variance: " +str(var8))
print("Range: from " +str(min8))
print("to  " +str(max8))
# Out:
# Mean: 4880.749392346391
# Median: 4741.0
# Mode: 0    4469.0
# dtype: float64
# Standard deviation: 1086.7762536416094
# Variance: 1181082.625479292
# Range: from 1800.0
# to  11008.0

# %%
import random
import csv

# %%
count1 = df['case_id'].count()
print ('count : ' + str(count1))
# Out:
# count : 318438

# %%
count1 = df['patientid'].count()
print ('count : ' + str(count1))
# Out:
# count : 318438

# %%
sample=r'C:\Users\ghpu\JupyterNotebook\datasets\healthcare\train.csv'
with open(sample) as f:
    reader = csv.reader(f)
    chosen_row1 = random.choice(list(reader))

# %%
print(chosen_row1)

# %%
sample=r'C:\Users\ghpu\JupyterNotebook\datasets\healthcare\randomsample.csv'
with open(sample) as f:
    reader = csv.reader(f)
    chosen_row2 = random.choice(list(reader))

# %%
print(chosen_row2)

# %%
sample=r'C:\Users\ghpu\JupyterNotebook\datasets\healthcare\randomsample.csv'
with open(sample) as f:
    reader = csv.reader(f)
    chosen_row3 = random.choice(list(reader))

# %%
print(chosen_row3)

# %%
type(chosen_row3)

# %%
row1=pd.DataFrame(chosen_row1)

# %%
type(row1)

# %%
row2=pd.DataFrame(chosen_row2)

# %%
row3=pd.DataFrame(chosen_row3)

# %%
row1

# %%
row1transposed=row1.transpose()

# %%
row1transposed

# %%
row1transposed.to_csv(r'C:\Users\ghpu\JupyterNotebook\datasets\healthcare\row1transposed.csv')

# %%
col_Names=[r"case_id", "Hospital_code", "Hospital_type_code", "City_Code_Hospital", "Hospital_region_code", "Available Extra Rooms in Hospital", "Department", "Ward_Type", "Ward_Facility_Code", "Bed Grade", "patientid","City_Code_Patient","Type of Admission","Severity of Illness","Visitors with Patient", "Age", "Admission_Deposit", "Stay"
]
sample= pd.read_csv(r"C:\Users\ghpu\JupyterNotebook\datasets\healthcare\row1transposed.csv",names=col_Names, header=None)

# %%
sample.to_csv(r'C:\Users\ghpu\JupyterNotebook\datasets\healthcare\temp1.csv')

# %%
sample

# %%
row1=sample.drop(sample.index[0])

# %%
row1.to_csv(r'C:\Users\ghpu\JupyterNotebook\datasets\healthcare\row1.csv')

# %%
row2

# %%
row2transposed=row2.transpose()

# %%
row2transposed.to_csv(r'C:\Users\ghpu\JupyterNotebook\datasets\healthcare\row2transposed.csv')

# %%
col_Names=[r"case_id", "Hospital_code", "Hospital_type_code", "City_Code_Hospital", "Hospital_region_code", "Available Extra Rooms in Hospital", "Department", "Ward_Type", "Ward_Facility_Code", "Bed Grade", "patientid","City_Code_Patient","Type of Admission","Severity of Illness","Visitors with Patient", "Age", "Admission_Deposit", "Stay"
]
sample= pd.read_csv(r"C:\Users\ghpu\JupyterNotebook\datasets\healthcare\row2transposed.csv",names=col_Names, header=None)

# %%
sample.to_csv(r'C:\Users\ghpu\JupyterNotebook\datasets\healthcare\temp2.csv')

# %%
sample

# %%
row2=sample.drop(sample.index[0])

# %%
row2.to_csv(r'C:\Users\ghpu\JupyterNotebook\datasets\healthcare\row2.csv')

# %%
row3

# %%
row3transposed=row3.transpose()

# %%
row3transposed

# %%
row3transposed.to_csv(r'C:\Users\ghpu\JupyterNotebook\datasets\healthcare\row3transposed.csv')

# %%
col_Names=[r"case_id", "Hospital_code", "Hospital_type_code", "City_Code_Hospital", "Hospital_region_code", "Available Extra Rooms in Hospital", "Department", "Ward_Type", "Ward_Facility_Code", "Bed Grade", "patientid","City_Code_Patient","Type of Admission","Severity of Illness","Visitors with Patient", "Age", "Admission_Deposit", "Stay"
]
sample= pd.read_csv(r"C:\Users\ghpu\JupyterNotebook\datasets\healthcare\row3transposed.csv",names=col_Names, header=None)

# %%
sample.to_csv(r'C:\Users\ghpu\JupyterNotebook\datasets\healthcare\temp3.csv')

# %%
sample

# %%
row3=sample.drop(sample.index[0])

# %%
row3.to_csv(r'C:\Users\ghpu\JupyterNotebook\datasets\healthcare\row3.csv')

# %%
row3

# %%
row3.case_id

# %%
type(row3.case_id)

# %%
row1.dtypes

# %%
row1.describe

# %%
patient1=row1
patient2=row2
patient3=row3

# %%
patient1

# %%
patient2

# %%
patient3

# %%
import seaborn as sns

# %%
ax = plt.gca()

ax.scatter([patient1.case_id], [patient1.Admission_Deposit], color="b", label='Patient 1')
ax.scatter([patient2.case_id], [patient2.Admission_Deposit], color="r", label='Patient 2')
ax.scatter([patient3.case_id], [patient3.Admission_Deposit], color="g", label='Patient 3')
plt.xlabel('Case ID')
plt.ylabel('Admission Deposit')
plt.title('Case ID vs Admission Deposit')
plt.legend()
plt.show()

# %%
patient1.columns = patient1.columns.str.replace(" ", "_")
patient2.columns = patient2.columns.str.replace(" ", "_")
patient3.columns = patient3.columns.str.replace(" ", "_")

# %%
patient3.Bed_Grade

# %%
patient3

# %%
ax = plt.gca()
ax.scatter([patient1.case_id], [patient1.Available_Extra_Rooms_in_Hospital], color="b", label='Patient 1')
ax.scatter([patient2.case_id], [patient2.Available_Extra_Rooms_in_Hospital], color="r", label='Patient 2')
ax.scatter([patient3.case_id], [patient3.Available_Extra_Rooms_in_Hospital], color="g", label='Patient 3')
plt.xlabel('Case ID')
plt.ylabel('Available Extra Rooms in Hospital')
plt.title('Case ID vs Bed Grade')
plt.legend()
plt.show()

# %%
ax = plt.gca()
ax.scatter([patient1.patientid], [patient1.Visitors_with_Patient], color="b", label='Patient 1')
ax.scatter([patient2.patientid], [patient2.Visitors_with_Patient], color="r", label='Patient 2')
ax.scatter([patient3.patientid], [patient3.Visitors_with_Patient], color="g", label='Patient 3')
plt.xlabel('Patient ID')
plt.ylabel('Visiters with Patient')
plt.title('Patient ID vs Visiters with Patient')
plt.legend()
plt.show()

# %%
import seaborn as sns

# %%
sample
# Out:
#      case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0         39             32                  f                   9
# 1        290             32                  f                   9
# 2        713             19                  a                   7
# 3        899             26                  b                   2
# 4       1065             26                  b                   2
# ..       ...            ...                ...                 ...
# 995   317019             27                  a                   7
# 996   317300             26                  b                   2
# 997   317685             26                  b                   2
# 998   317813              6                  a                   6
# 999   318372              7                  a                   4
#
#     Hospital_region_code  Available Extra Rooms in Hospital  \
# 0                      Y                                  2
# ...

# %%
sns.catplot("case_id", "Available Extra Rooms in Hospital", data=sample, jitter=False)

# %%
sns.catplot("Department", "case_id", data=sample, jitter=False)

# %%
sns.catplot("case_id", "Bed Grade", data=sample, jitter=False, kind="violin")

# %%
sns.catplot("Type of Admission", "patientid", data=sample, jitter=False, kind="violin")

# %%
sns.scatterplot(data=sample["Admission_Deposit"])

# %%
sns.relplot(
    data=sample, x="patientid", y="Visitors with Patient",
    kind="line"
)

# %%
sns.relplot(
    data=sample, x="Age", y="case_id",
    kind="line"
)

# %%
sns.relplot(
    data=sample, x="Age", y="case_id",
    kind="line"
)

# %%
sns.relplot(
    data=sample, x="Stay", y="case_id",
    kind="scatter"
)

# %%
sns.swarmplot("Severity of Illness", "patientid", data=sample)

# %%
sample
# Out:
#      case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0         39             32                  f                   9
# 1        290             32                  f                   9
# 2        713             19                  a                   7
# 3        899             26                  b                   2
# 4       1065             26                  b                   2
# ..       ...            ...                ...                 ...
# 995   317019             27                  a                   7
# 996   317300             26                  b                   2
# 997   317685             26                  b                   2
# 998   317813              6                  a                   6
# 999   318372              7                  a                   4
#
#     Hospital_region_code  Available Extra Rooms in Hospital  \
# 0                      Y                                  2
# ...
